# %%
import sys
sys.path.append("../")

from electronfactors.model.display_cutouts import display_cutouts
# %matplotlib inline

# %%
display_cutouts()
# Out:
# model_cache/12MeV_10app_100ssd.yml
# ...
#
#   - Simon 9cm circle
#     - Width: 9.00
#     - Length: 9.00
#     - Measured Factor: 1.0084
#     - Predicted Factor: 1.0189
#   - Simon #73 cutout
#     - Width: 7.18
#     - Length: 9.54
#     - Measured Factor: 1.0045
#     - Predicted Factor: 1.0036
#   - P22
#     - Width: 7.19
#     - Length: 9.79
#     - Measured Factor: 0.9990
#     - Predicted Factor: 1.0042
#   - Simon #20 cutout
#     - Width: 4.28
#     - Length: 5.10
#     - Measured Factor: 0.9634
#     - Predicted Factor: 0.9627
#   - Simon #104 cutout
#     - Width: 5.61
#     - Length: 8.34
#     - Measured Factor: 0.9934
#     - Predicted Factor: 0.9871
#   - Simon #109 cutout
#     - Width: 6.31
#     - Length: 7.76
#     - Measured Factor: 0.9931
#     - Predicted Factor: 0.9930
#   - Simon #3 cutout
#     - Width: 4.50
#     - Length: 6.05
#     - Measured Factor: 0.9683
#     - Predicted Factor: 0.9693
#   - Simon 6cm circle
#     - Width: 6.00
#     - Length: 6.00
# ...
