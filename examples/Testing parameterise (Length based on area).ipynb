# %%
import yaml
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

import traceback
from glob import glob

import sys
sys.path.append("../")

from electronfactors.inputs.convert_merge import convert_merge
from electronfactors.model.parameterise import parameterise
from electronfactors.model.sort import create_cache
from electronfactors.ellipse.equivalent import equivalent_ellipse

# %%
convert_merge()

# %%
# working_directory="imported_data/"

# input_filepath = working_directory + "merged.yml"

# with open(input_filepath, 'r') as file:
#     input_dict = yaml.load(file)

# key_list = ['P15_1']
# for i, key in enumerate(key_list):
#     XCoords = input_dict[key]['XCoords']
#     YCoords = input_dict[key]['YCoords']

#     print(str(key) + ":")
#     ellipse = equivalent_ellipse(
#         XCoords=XCoords, YCoords=YCoords)

# %%
parameterise(display=True)
# Out:
# Simon #73 cutout:
# P6:
# P31_1:
# P25:
# Simon #20 cutout:
# Simon 4x13cm oval:
# Simon #43 cutout:
# P35_1:
# Simon #112 cutout:
# Simon 5x10cm oval:
# Simon #58 cutout:
# Simon #32 cutout:
# Simon 8cm circle:
# Simon 7cm circle:
# P36_2:
# P38_3:
# Simon #82 cutout:
# P46:
# P37_3:
# P21:
# P22:
# P26:
# Simon #16 cutout:
# Simon 6cm circle:
# Simon #57 cutout:
# P15_1:
# P36_1:
# P33:
# Simon #104 cutout:
# Simon 4x10cm oval:
# P5_2:
# P23:
# Simon #3 cutout:
# Simon #33 cutout:
# Simon 4x8cm oval:
# P37_1:
# P4:
# P7:
# Simon 5x8cm oval:
# P3:
# P14_1:
# Simon 4x6.5cm oval:
# Simon 4cm circle:
# Simon #18 cutout:
# P8:
# P35_3:
# Simon #14 cutout:
# P28:
# Simon 3x6.5cm oval:
# Simon #41 cutout:
# P13:
# P41:
# P32:
# Simon 3x13cm oval:
# P17:
# P27:
# P37_4:
# Simon 3x5cm oval:
# P2:
# P34_1:
# P31_2:
# P19:
# Simon #34 cutout:
# P15_2:
# P34_2:
# Simon #38 cutout:
# Simon #83 cutout:
# Simon 5x13cm oval:
# P12_2:
# P40:
# P45:
# Simon #22 cutout:
# P35_2:
# P53:
# Simon 5cm circle:
# Simon #6 cutout:
# P24:
# P38_1:
# P14_2:
# P34_3:
# P18:
# P10:
# P30:
# Simon #70 cutout:
# Simon #106 cutout:
# Simon #109 cutout:
# P20:
# Simon 3x9cm oval:
# P42:
# P12_1:
# P38_2:
# Simon 3cm circle:
# Simon #19 cutout:
# Simon 9cm circle:

# %%
energy_list = [6, 9, 12, 15, 18]
app_list = [6, 10, 14, 20, 25]

# energy_list = [18]
# app_list = [10]

for energy in energy_list:
    for applicator in app_list:
        try:
            create_cache(energy=energy, applicator=applicator)
            print("SUCCESS\nEnergy = %d\nApplicator = %d" % (energy, applicator))
            sys.stdout.flush()
        except:
            print("FAILED\nEnergy = %d\nApplicator = %d" % (energy, applicator))
            traceback.print_exc()
            print(" ")
            sys.stdout.flush()
# Out:
# FAILED
# Energy = 6
# Applicator = 6
# Traceback (most recent call last):
#   File "<ipython-input-5-bdc05ceeb60a>", line 10, in <module>
#     create_cache(energy=energy, applicator=applicator)
#   File "../electronfactors/model/sort.py", line 49, in create_cache
#     raise Exception("Not sufficient data points")
# Exception: Not sufficient data points
# Traceback (most recent call last):
# FAILED
# Energy = 6
# Applicator = 10
#
# SUCCESS
# Energy = 6
# Applicator = 14
#   File "<ipython-input-5-bdc05ceeb60a>", line 10, in <module>
#     create_cache(energy=energy, applicator=applicator)
#   File "../electronfactors/model/sort.py", line 49, in create_cache
#     raise Exception("Not sufficient data points")
# Exception: Not sufficient data points
# Traceback (most recent call last):
# FAILED
# Energy = 6
# Applicator = 20
#   File "<ipython-input-5-bdc05ceeb60a>", line 10, in <module>
#     create_cache(energy=energy, applicator=applicator)
#   File "../electronfactors/model/sort.py", line 49, in create_cache
#     raise Exception("Not sufficient data points")
# Exception: Not sufficient data points
# Traceback (most recent call last):
# FAILED
# Energy = 6
# Applicator = 25
#   File "<ipython-input-5-bdc05ceeb60a>", line 10, in <module>
#     create_cache(energy=energy, applicator=applicator)
#   File "../electronfactors/model/sort.py", line 49, in create_cache
#     raise Exception("Not sufficient data points")
# Exception: Not sufficient data points
# Traceback (most recent call last):
# FAILED
# Energy = 9
# Applicator = 6
#
# SUCCESS
# Energy = 9
# Applicator = 10
# SUCCESS
# Energy = 9
# Applicator = 14
#   File "<ipython-input-5-bdc05ceeb60a>", line 10, in <module>
#     create_cache(energy=energy, applicator=applicator)
#   File "../electronfactors/model/sort.py", line 49, in create_cache
#     raise Exception("Not sufficient data points")
# Exception: Not sufficient data points
# Traceback (most recent call last):
# FAILED
# Energy = 9
# Applicator = 20
#   File "<ipython-input-5-bdc05ceeb60a>", line 10, in <module>
#     create_cache(energy=energy, applicator=applicator)
#   File "../electronfactors/model/sort.py", line 49, in create_cache
#     raise Exception("Not sufficient data points")
# Exception: Not sufficient data points
# Traceback (most recent call last):
# FAILED
# Energy = 9
# Applicator = 25
#   File "<ipython-input-5-bdc05ceeb60a>", line 10, in <module>
#     create_cache(energy=energy, applicator=applicator)
#   File "../electronfactors/model/sort.py", line 49, in create_cache
#     raise Exception("Not sufficient data points")
# Exception: Not sufficient data points
# Traceback (most recent call last):
# FAILED
# Energy = 12
# Applicator = 6
#
# SUCCESS
# Energy = 12
# Applicator = 10
#   File "<ipython-input-5-bdc05ceeb60a>", line 10, in <module>
#     create_cache(energy=energy, applicator=applicator)
#   File "../electronfactors/model/sort.py", line 49, in create_cache
#     raise Exception("Not sufficient data points")
# Exception: Not sufficient data points
# Traceback (most recent call last):
# FAILED
# Energy = 12
# Applicator = 14
#   File "<ipython-input-5-bdc05ceeb60a>", line 10, in <module>
#     create_cache(energy=energy, applicator=applicator)
#   File "../electronfactors/model/sort.py", line 49, in create_cache
#     raise Exception("Not sufficient data points")
# Exception: Not sufficient data points
# Traceback (most recent call last):
# FAILED
# Energy = 12
# Applicator = 20
#   File "<ipython-input-5-bdc05ceeb60a>", line 10, in <module>
#     create_cache(energy=energy, applicator=applicator)
#   File "../electronfactors/model/sort.py", line 49, in create_cache
#     raise Exception("Not sufficient data points")
# Exception: Not sufficient data points
# Traceback (most recent call last):
# FAILED
# Energy = 12
# Applicator = 25
#   File "<ipython-input-5-bdc05ceeb60a>", line 10, in <module>
#     create_cache(energy=energy, applicator=applicator)
#   File "../electronfactors/model/sort.py", line 49, in create_cache
#     raise Exception("Not sufficient data points")
# Exception: Not sufficient data points
# Traceback (most recent call last):
# FAILED
# Energy = 15
# Applicator = 6
#   File "<ipython-input-5-bdc05ceeb60a>", line 10, in <module>
#     create_cache(energy=energy, applicator=applicator)
#   File "../electronfactors/model/sort.py", line 49, in create_cache
#     raise Exception("Not sufficient data points")
# Exception: Not sufficient data points
# Traceback (most recent call last):
# FAILED
# Energy = 15
# Applicator = 10
#   File "<ipython-input-5-bdc05ceeb60a>", line 10, in <module>
#     create_cache(energy=energy, applicator=applicator)
#   File "../electronfactors/model/sort.py", line 49, in create_cache
#     raise Exception("Not sufficient data points")
# Exception: Not sufficient data points
# Traceback (most recent call last):
# FAILED
# Energy = 15
# Applicator = 14
#   File "<ipython-input-5-bdc05ceeb60a>", line 10, in <module>
#     create_cache(energy=energy, applicator=applicator)
#   File "../electronfactors/model/sort.py", line 49, in create_cache
#     raise Exception("Not sufficient data points")
# Exception: Not sufficient data points
# Traceback (most recent call last):
# FAILED
# Energy = 15
# Applicator = 20
#   File "<ipython-input-5-bdc05ceeb60a>", line 10, in <module>
#     create_cache(energy=energy, applicator=applicator)
#   File "../electronfactors/model/sort.py", line 49, in create_cache
#     raise Exception("Not sufficient data points")
# Exception: Not sufficient data points
# Traceback (most recent call last):
# FAILED
# Energy = 15
# Applicator = 25
#   File "<ipython-input-5-bdc05ceeb60a>", line 10, in <module>
#     create_cache(energy=energy, applicator=applicator)
#   File "../electronfactors/model/sort.py", line 49, in create_cache
#     raise Exception("Not sufficient data points")
# Exception: Not sufficient data points
# Traceback (most recent call last):
# FAILED
# Energy = 18
# Applicator = 6
#
# SUCCESS
# Energy = 18
# Applicator = 10
#   File "<ipython-input-5-bdc05ceeb60a>", line 10, in <module>
#     create_cache(energy=energy, applicator=applicator)
#   File "../electronfactors/model/sort.py", line 49, in create_cache
#     raise Exception("Not sufficient data points")
# Exception: Not sufficient data points
# Traceback (most recent call last):
# FAILED
# Energy = 18
# Applicator = 14
#   File "<ipython-input-5-bdc05ceeb60a>", line 10, in <module>
#     create_cache(energy=energy, applicator=applicator)
#   File "../electronfactors/model/sort.py", line 49, in create_cache
#     raise Exception("Not sufficient data points")
# Exception: Not sufficient data points
# Traceback (most recent call last):
# FAILED
# Energy = 18
# Applicator = 20
#   File "<ipython-input-5-bdc05ceeb60a>", line 10, in <module>
#     create_cache(energy=energy, applicator=applicator)
#   File "../electronfactors/model/sort.py", line 49, in create_cache
#     raise Exception("Not sufficient data points")
# Exception: Not sufficient data points
# Traceback (most recent call last):
# FAILED
# Energy = 18
# Applicator = 25
#   File "<ipython-input-5-bdc05ceeb60a>", line 10, in <module>
#     create_cache(energy=energy, applicator=applicator)
#   File "../electronfactors/model/sort.py", line 49, in create_cache
#     raise Exception("Not sufficient data points")
# Exception: Not sufficient data points
