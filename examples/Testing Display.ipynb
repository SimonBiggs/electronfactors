# %%
import sys
sys.path.append("../")

from electronfactors.model.display_cutouts import load_and_display
# %matplotlib inline

# %%
load_and_display()
# Out:
# model_cache/12MeV_10app_100ssd.yml
# ...
#
#   - Simon #82 cutout
#     - Width: 6.28
#     - Length: 7.58
#     - Measured Factor: 0.9991
#   - Simon #16 cutout
#     - Width: 6.18
#     - Length: 10.24
#     - Measured Factor: 1.0004
#   - Simon 3x5cm oval
#     - Width: 3.00
#     - Length: 5.00
#     - Measured Factor: 0.9348
#   - Simon #109 cutout
#     - Width: 6.48
#     - Length: 7.64
#     - Measured Factor: 0.9931
#   - Simon #41 cutout
#     - Width: 6.88
#     - Length: 10.09
#     - Measured Factor: 1.0052
#   - Simon 3x9cm oval
#     - Width: 3.00
#     - Length: 9.00
#     - Measured Factor: 0.9492
#   - Simon 4x8cm oval
#     - Width: 4.00
#     - Length: 8.00
#     - Measured Factor: 0.9708
#   - Simon 4x10cm oval
#     - Width: 4.00
#     - Length: 10.00
#     - Measured Factor: 0.9709
#   - Simon 5cm circle
#     - Width: 5.00
#     - Length: 5.00
#     - Measured Factor: 0.9705
#   - P40
#     - Width: 5.80
#     - Length: 10.18
#     - Measured Factor: 0.9872
# ...
