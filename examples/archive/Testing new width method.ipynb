# %%
import yaml
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

import sys
sys.path.append("../")

from electronfactors.model.parameterise import parameterise

# %%
with open("imported_data/~parameterised.yml", 'r') as file:
    previous_dict = yaml.load(file)

# %%
parameterise(display=True)
# Out:
# Simon #20 cutout:
# Simon 6cm circle:
# P14_2:
# P6:
# P21:
# Simon 8cm circle:
# Simon #41 cutout:
# P37_3:
# Simon 3x5cm oval:
# P40:
# P37_1:
# P42:
# P38_3:
# Simon 9cm circle:
# P27:
# Simon #82 cutout:
# P15_2:
# P35_2:
# P2:
# Simon 4x6.5cm oval:
# Simon #112 cutout:
# Simon 4cm circle:
# P25:
# Simon 3x9cm oval:
# Simon 5cm circle:
# Simon #32 cutout:
# P19:
# Simon #3 cutout:
# P26:
# P34_1:
# Simon #58 cutout:
# P18:
# P31_2:
# P10:
# Simon 3x13cm oval:
# P17:
# P31_1:
# P15_1:
# Simon #106 cutout:
# Simon #70 cutout:
# Simon 3cm circle:
# P45:
# Simon #14 cutout:
# P53:
# P23:
# Simon #33 cutout:
# Simon 5x8cm oval:
# P5_2:
# P22:
# P33:
# P34_3:
# Simon 5x10cm oval:
# Simon 4x10cm oval:
# P12_1:
# P38_2:
# P13:
# P4:
# P7:
# Simon #18 cutout:
# P38_1:
# Simon 5x13cm oval:
# Simon #19 cutout:
# Simon #6 cutout:
# P46:
# Simon #43 cutout:
# P36_2:
# Simon #34 cutout:
# Simon 7cm circle:
# P35_1:
# Simon #104 cutout:
# Simon 4x13cm oval:
# P34_2:
# Simon #16 cutout:
# P32:
# ...

# %%
with open("imported_data/parameterised.yml", 'r') as file:
    new_dict = yaml.load(file)

# %%
width_diff = [
    new_dict[key]['width'] - previous_dict[key]['width'] for key in new_dict
]
    
plt.plot(width_diff)
