# %%
import sys
sys.path.append("../")

from electronfactors.model.display_cutouts import display_cutouts
# %matplotlib inline

# %%
display_cutouts()
# Out:
# model_cache/12MeV_10app_100ssd.yml
# ...
#
#   - Simon 9cm circle
#     - Width: 9.00
#     - Length: 9.00
#     - Measured Factor: 1.0084
#     - Predicted Factor: 1.0028
#   - Simon #3 cutout
#     - Width: 4.48
#     - Length: 6.08
#     - Measured Factor: 0.9683
#     - Predicted Factor: 0.9692
#   - Simon 3cm circle
#     - Width: 2.99
#     - Length: 3.00
#     - Measured Factor: 0.9296
#     - Predicted Factor: 0.9385
#   - Simon 7cm circle
#     - Width: 7.00
#     - Length: 7.00
#     - Measured Factor: 1.0032
#     - Predicted Factor: 1.0012
#   - Simon #22 cutout
#     - Width: 5.13
#     - Length: 10.31
#     - Measured Factor: 0.9884
#     - Predicted Factor: 0.9891
#   - Simon #34 cutout
#     - Width: 6.89
#     - Length: 9.94
#     - Measured Factor: 1.0067
#     - Predicted Factor: 1.0028
#   - Simon #38 cutout
#     - Width: 4.63
#     - Length: 5.72
#     - Measured Factor: 0.9735
#     - Predicted Factor: 0.9693
#   - Simon #18 cutout
#     - Width: 7.60
# ...
