# %%
# %matplotlib inline

from electronfactors import convert_merge, parameterise, cache_all

# %%
convert_merge(
    input_directory="user_inputs/", 
    output_directory="imported_data/")

# %%
parameterise(
    working_directory="imported_data/", 
    display=True, optimise_position=True)
# Out:
# Simon #104 cutout:
# Simon #106 cutout:
# Simon #109 cutout:
# Simon #112 cutout:
# Simon #14 cutout:
# Simon #16 cutout:
# Simon #18 cutout:
# Simon #19 cutout:
# Simon #20 cutout:
# Simon #22 cutout:
# Simon #3 cutout:
# Simon #32 cutout:
# Simon #33 cutout:
# Simon #34 cutout:
# Simon #38 cutout:
# Simon #41 cutout:
# Simon #43 cutout:
# Simon #57 cutout:
# Simon #58 cutout:
# Simon #6 cutout:
# Simon #70 cutout:
# Simon #73 cutout:
# Simon #82 cutout:
# Simon #83 cutout:
# Simon 3cm circle:
# Simon 3x13cm oval:
# Simon 3x5cm oval:
# Simon 3x6.5cm oval:
# Simon 3x9cm oval:
# Simon 4cm circle:
# Simon 4x10cm oval:
# Simon 4x13cm oval:
# Simon 4x6.5cm oval:
# Simon 4x8cm oval:
# Simon 5cm circle:
# Simon 5x10cm oval:
# Simon 5x13cm oval:
# Simon 5x8cm oval:
# Simon 6cm circle:
# Simon 7cm circle:
# Simon 8cm circle:
# Simon 9cm circle:

# %%
cache_all(
    input_directory="imported_data/", output_directory="model_cache/")
# Out:
# Cache created
# Number of measurements = 42
# Energy = 12
# Applicator = 10
# SSD = 100
