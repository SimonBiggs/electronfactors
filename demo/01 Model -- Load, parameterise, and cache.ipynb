# %%
# %matplotlib inline

import sys
sys.path.append("../")

from electronfactors.inputs.convert_merge import convert_merge
from electronfactors.model.parameterise import parameterise
from electronfactors.model.sort import cache_all

# %%
convert_merge()

# %%
parameterise(display=True, optimise_position=True)
# Out:
# Simon 3cm circle:
# Simon 4cm circle:
# Simon #14 cutout:
# Simon 3x13cm oval:
# Simon 4x13cm oval:
# Simon #43 cutout:
# Simon #83 cutout:
# Simon 4x10cm oval:
# Simon #38 cutout:
# Simon #18 cutout:
# Simon #82 cutout:
# Simon #3 cutout:
# Simon 3x9cm oval:
# Simon #16 cutout:
# Simon 8cm circle:
# Simon #41 cutout:
# Simon 4x6.5cm oval:
# Simon 3x6.5cm oval:
# Simon #6 cutout:
# Simon #104 cutout:
# Simon #32 cutout:
# Simon #109 cutout:
# Simon #20 cutout:
# Simon #57 cutout:
# Simon #58 cutout:
# Simon #112 cutout:
# Simon #70 cutout:
# Simon #73 cutout:
# Simon #33 cutout:
# Simon 6cm circle:
# Simon #19 cutout:
# Simon #106 cutout:
# Simon 5x8cm oval:
# Simon 5x10cm oval:
# Simon #34 cutout:
# Simon #22 cutout:
# Simon 5cm circle:
# Simon 3x5cm oval:
# Simon 5x13cm oval:
# Simon 9cm circle:
# Simon 7cm circle:
# Simon 4x8cm oval:

# %%
cache_all()
# Out:
# Cache created
# Number of measurements = 42
# Energy = 12
# Applicator = 10
# SSD = 100
