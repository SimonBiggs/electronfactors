# %%
import yaml
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

import traceback
from glob import glob

import sys
sys.path.append("../")

from electronfactors.inputs.convert_merge import convert_merge
from electronfactors.model.parameterise import parameterise
from electronfactors.model.sort import create_cache
from electronfactors.ellipse.equivalent import equivalent_ellipse

# %%
convert_merge()

# %%
parameterise(display=True)
# Out:
# P34_1:
# Simon 5.3x12.5cm_15MeV:
# P6:
# Simon #82 cutout:
# P3:
# Simon #18 cutout:
# Simon 5cm_18MeV:
# Simon #106 cutout:
# P23:
# Simon 9.5cm_18MeV:
# Simon 7.25cm_15MeV:
# Simon #109 cutout:
# P31_2:
# P24:
# P35_2:
# Simon #33 cutout:
# P32:
# P21:
# Simon #58 cutout:
# P7:
# Simon 4x10cm oval:
# P12_1:
# Simon #20 cutout:
# P13:
# Simon 8.3cm_15MeV:
# Simon 5cm_6MeV:
# Simon 3x13cm oval:
# Simon 4x8cm oval:
# P34_3:
# P14_2:
# Simon #57 cutout:
# P2:
# Simon #14 cutout:
# Simon 6cm circle:
# Simon 5.3x12.5cm_6MeV:
# Simon #32 cutout:
# P25:
# P8:
# Simon 5cm circle:
# Simon #73 cutout:
# P20:
# Simon 5x13cm oval:
# Simon 8.3cm_9MeV:
# P36_1:
# Simon #6 cutout:
# Simon 5x10cm oval:
# Simon 6.1cm_18MeV:
# Simon 7.25cm_6MeV:
# Simon 9.5cm_9MeV:
# Simon #3 cutout:
# Simon #70 cutout:
# Simon 3x6.5cm oval:
# P5_2:
# P4:
# P10:
# P28:
# Simon 7.25cm_9MeV:
# Simon #16 cutout:
# Simon 4x13cm oval:
# P37_1:
# Simon 9.5cm_15MeV:
# P37_3:
# Simon 3x5cm oval:
# Simon #43 cutout:
# Simon 6.1cm_6MeV:
# Simon 4cm circle:
# P31_1:
# Simon 5.3x12.5cm_18MeV:
# P26:
# Simon 5cm_15MeV:
# P15_1:
# Simon 3cm circle:
# Simon 9.5cm_6MeV:
# Simon #104 cutout:
# P22:
# P30:
# Simon 6.7x12cm_6MeV:
# Simon #22 cutout:
# P33:
# P18:
# P53:
# Simon 4x6.5cm oval:
# Simon 8cm circle:
# P19:
# Simon 9cm circle:
# P38_3:
# Simon 7.25cm_18MeV:
# P42:
# P17:
# Simon 6.7x12cm_15MeV:
# P45:
# Simon 7cm circle:
# P41:
# Simon 8.5x10.9cm_18MeV:
# P35_3:
# Simon 3x9cm oval:
# Simon 6.1cm_15MeV:
# Simon #83 cutout:
# P35_1:
# P14_1:
# Simon 8.3cm_18MeV:
# P46:
# P34_2:
# Simon #112 cutout:
# P12_2:
# P36_2:
# Simon 8.5x10.9cm_15MeV:
# Simon 5x8cm oval:
# Simon 8.5x10.9cm_9MeV:
# Simon #34 cutout:
# Simon #38 cutout:
# Simon 5.3x12.5cm_9MeV:
# P15_2:
# Simon 5cm_9MeV:
# P38_1:
# Simon #41 cutout:
# Simon 6.1cm_9MeV:
# Simon 6.7x12cm_18MeV:
# P37_4:
# Simon 8.3cm_6MeV:
# P38_2:
# Simon 8.5x10.9cm_6MeV:
# P40:
# P27:
# Simon 6.7x12cm_9MeV:
# Simon #19 cutout:

# %%
energy_list = [6, 9, 12, 15, 18]
app_list = [6, 10, 14, 20, 25]

# energy_list = [18]
# app_list = [10]

for energy in energy_list:
    for applicator in app_list:
        try:
            create_cache(energy=energy, applicator=applicator)
            print("SUCCESS\nEnergy = %d\nApplicator = %d" % (energy, applicator))
            sys.stdout.flush()
        except:
            print("FAILED\nEnergy = %d\nApplicator = %d" % (energy, applicator))
            traceback.print_exc()
            print(" ")
            sys.stdout.flush()
# Out:
# FAILED
# Energy = 6
# Applicator = 6
#
# SUCCESS
# Energy = 6
# Applicator = 10
# Traceback (most recent call last):
#   File "<ipython-input-4-bdc05ceeb60a>", line 10, in <module>
#     create_cache(energy=energy, applicator=applicator)
#   File "../electronfactors/model/sort.py", line 49, in create_cache
#     raise Exception("Not sufficient data points")
# Exception: Not sufficient data points
# Traceback (most recent call last):
# FAILED
# Energy = 6
# Applicator = 14
#   File "<ipython-input-4-bdc05ceeb60a>", line 10, in <module>
#     create_cache(energy=energy, applicator=applicator)
#   File "../electronfactors/model/sort.py", line 49, in create_cache
#     raise Exception("Not sufficient data points")
# Exception: Not sufficient data points
# Traceback (most recent call last):
# FAILED
# Energy = 6
# Applicator = 20
#   File "<ipython-input-4-bdc05ceeb60a>", line 10, in <module>
#     create_cache(energy=energy, applicator=applicator)
#   File "../electronfactors/model/sort.py", line 49, in create_cache
#     raise Exception("Not sufficient data points")
# Exception: Not sufficient data points
# Traceback (most recent call last):
# FAILED
# Energy = 6
# Applicator = 25
#   File "<ipython-input-4-bdc05ceeb60a>", line 10, in <module>
#     create_cache(energy=energy, applicator=applicator)
#   File "../electronfactors/model/sort.py", line 49, in create_cache
#     raise Exception("Not sufficient data points")
# Exception: Not sufficient data points
# Traceback (most recent call last):
# FAILED
# Energy = 9
# Applicator = 6
#
# SUCCESS
# Energy = 9
# Applicator = 10
#   File "<ipython-input-4-bdc05ceeb60a>", line 10, in <module>
#     create_cache(energy=energy, applicator=applicator)
#   File "../electronfactors/model/sort.py", line 49, in create_cache
#     raise Exception("Not sufficient data points")
# Exception: Not sufficient data points
# Traceback (most recent call last):
# FAILED
# Energy = 9
# Applicator = 14
#   File "<ipython-input-4-bdc05ceeb60a>", line 10, in <module>
#     create_cache(energy=energy, applicator=applicator)
#   File "../electronfactors/model/sort.py", line 49, in create_cache
#     raise Exception("Not sufficient data points")
# Exception: Not sufficient data points
# Traceback (most recent call last):
# FAILED
# Energy = 9
# Applicator = 20
#   File "<ipython-input-4-bdc05ceeb60a>", line 10, in <module>
#     create_cache(energy=energy, applicator=applicator)
#   File "../electronfactors/model/sort.py", line 49, in create_cache
#     raise Exception("Not sufficient data points")
# Exception: Not sufficient data points
# Traceback (most recent call last):
# FAILED
# Energy = 9
# Applicator = 25
#   File "<ipython-input-4-bdc05ceeb60a>", line 10, in <module>
#     create_cache(energy=energy, applicator=applicator)
#   File "../electronfactors/model/sort.py", line 49, in create_cache
#     raise Exception("Not sufficient data points")
# Exception: Not sufficient data points
# Traceback (most recent call last):
# FAILED
# Energy = 12
# Applicator = 6
#
# SUCCESS
# Energy = 12
# Applicator = 10
#   File "<ipython-input-4-bdc05ceeb60a>", line 10, in <module>
#     create_cache(energy=energy, applicator=applicator)
#   File "../electronfactors/model/sort.py", line 49, in create_cache
#     raise Exception("Not sufficient data points")
# Exception: Not sufficient data points
# Traceback (most recent call last):
# FAILED
# Energy = 12
# Applicator = 14
#   File "<ipython-input-4-bdc05ceeb60a>", line 10, in <module>
#     create_cache(energy=energy, applicator=applicator)
#   File "../electronfactors/model/sort.py", line 49, in create_cache
#     raise Exception("Not sufficient data points")
# Exception: Not sufficient data points
# Traceback (most recent call last):
# FAILED
# Energy = 12
# Applicator = 20
#   File "<ipython-input-4-bdc05ceeb60a>", line 10, in <module>
#     create_cache(energy=energy, applicator=applicator)
#   File "../electronfactors/model/sort.py", line 49, in create_cache
#     raise Exception("Not sufficient data points")
# Exception: Not sufficient data points
# Traceback (most recent call last):
# FAILED
# Energy = 12
# Applicator = 25
#   File "<ipython-input-4-bdc05ceeb60a>", line 10, in <module>
#     create_cache(energy=energy, applicator=applicator)
#   File "../electronfactors/model/sort.py", line 49, in create_cache
#     raise Exception("Not sufficient data points")
# Exception: Not sufficient data points
# Traceback (most recent call last):
# FAILED
# Energy = 15
# Applicator = 6
#
# SUCCESS
# Energy = 15
# Applicator = 10
#   File "<ipython-input-4-bdc05ceeb60a>", line 10, in <module>
#     create_cache(energy=energy, applicator=applicator)
#   File "../electronfactors/model/sort.py", line 49, in create_cache
#     raise Exception("Not sufficient data points")
# Exception: Not sufficient data points
# Traceback (most recent call last):
# FAILED
# Energy = 15
# Applicator = 14
#   File "<ipython-input-4-bdc05ceeb60a>", line 10, in <module>
#     create_cache(energy=energy, applicator=applicator)
#   File "../electronfactors/model/sort.py", line 49, in create_cache
#     raise Exception("Not sufficient data points")
# Exception: Not sufficient data points
# Traceback (most recent call last):
# FAILED
# Energy = 15
# Applicator = 20
#   File "<ipython-input-4-bdc05ceeb60a>", line 10, in <module>
#     create_cache(energy=energy, applicator=applicator)
#   File "../electronfactors/model/sort.py", line 49, in create_cache
#     raise Exception("Not sufficient data points")
# Exception: Not sufficient data points
# Traceback (most recent call last):
# FAILED
# Energy = 15
# Applicator = 25
#   File "<ipython-input-4-bdc05ceeb60a>", line 10, in <module>
#     create_cache(energy=energy, applicator=applicator)
#   File "../electronfactors/model/sort.py", line 49, in create_cache
#     raise Exception("Not sufficient data points")
# Exception: Not sufficient data points
# Traceback (most recent call last):
# FAILED
# Energy = 18
# Applicator = 6
#
# SUCCESS
# Energy = 18
# Applicator = 10
#   File "<ipython-input-4-bdc05ceeb60a>", line 10, in <module>
#     create_cache(energy=energy, applicator=applicator)
#   File "../electronfactors/model/sort.py", line 49, in create_cache
#     raise Exception("Not sufficient data points")
# Exception: Not sufficient data points
# Traceback (most recent call last):
# FAILED
# Energy = 18
# Applicator = 14
#   File "<ipython-input-4-bdc05ceeb60a>", line 10, in <module>
#     create_cache(energy=energy, applicator=applicator)
#   File "../electronfactors/model/sort.py", line 49, in create_cache
#     raise Exception("Not sufficient data points")
# Exception: Not sufficient data points
# Traceback (most recent call last):
# FAILED
# Energy = 18
# Applicator = 20
#   File "<ipython-input-4-bdc05ceeb60a>", line 10, in <module>
#     create_cache(energy=energy, applicator=applicator)
#   File "../electronfactors/model/sort.py", line 49, in create_cache
#     raise Exception("Not sufficient data points")
# Exception: Not sufficient data points
# Traceback (most recent call last):
# FAILED
# Energy = 18
# Applicator = 25
#   File "<ipython-input-4-bdc05ceeb60a>", line 10, in <module>
#     create_cache(energy=energy, applicator=applicator)
#   File "../electronfactors/model/sort.py", line 49, in create_cache
#     raise Exception("Not sufficient data points")
# Exception: Not sufficient data points
